# %%
import bay12_scraper

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
import os

# %%
p_data = os.path.abspath('../output')

# %% [markdown]
# ----

# %% [markdown]
# # Exploring thread types

# %%
p_threads = os.path.join(p_data, 'threads.csv')
df_threads = pd.read_csv(p_threads, header=0, encoding='utf-8')

# %%
df_threads.head()
# Out:
#                                                  url  thread_num  \
# 0  http://www.bay12forums.com/smf/index.php?topic...      134925
# 1  http://www.bay12forums.com/smf/index.php?topic...       45016
# 2  http://www.bay12forums.com/smf/index.php?topic...      126856
# 3  http://www.bay12forums.com/smf/index.php?topic...       88720
# 4  http://www.bay12forums.com/smf/index.php?topic...      144075
#
#                                          thread_name thread_label  \
# 0                  Mafia Setup Discussion and Review        other
# 1  Games Threshold Discussion and List [Vote for ...        other
# 2  Mafia Tools and Utilities (lurkertracker, etc)...        other
# 3  New Player's Guide to the Subforum - New to Ma...        other
# 4              Notable Games Archive: The New Thread        other
#
#    thread_replies
# 0             598
# 1            5703
# 2              38
# 3             961
# 4              40

# %%
df_thread_stats = df_threads.groupby('thread_label')['thread_replies'].agg(['count', 'sum'])
df_thread_stats.columns = ['threads', 'posts']
df_thread_stats['posts'] += df_thread_stats['threads']  # counting original post (1) + replies

# Set "usefulness" measure
df_thread_stats['usefulness'] = 0
usf = {
    3: ['beginners-mafia', 'vanilla'], 
    2: ['classic', 'vengeful', 'supernatural'],
    1: ['closed-setup', 'paranormal', 'kotm'] + ['byor', 'bastard', 'cybrid'],
}
for k, v in usf.items():
    df_thread_stats.usefulness[v] = k
    
# Set and sort index
df_thread_stats = df_thread_stats.reset_index().set_index(['usefulness', 'thread_label']).sort_index(ascending=[False, True])

# %%
df_thread_stats.style.bar()
# Out:
# <style  type="text/css" >
#     #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.5%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 74.2%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.6%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.2%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.8%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 46.1%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.1%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.2%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.0%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.4%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 57.4%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.3%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.4%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.8%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.6%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow8_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow8_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.4%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.1%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.9%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.0%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.3%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }</style>
# <table id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6dd" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >threads</th>
#         <th class="col_heading level0 col1" >posts</th>
#     </tr>    <tr>
#         <th class="index_name level0" >usefulness</th>
#         <th class="index_name level1" >thread_label</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddlevel0_row0" class="row_heading level0 row0" rowspan=2>3</th>
#         <th id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddlevel1_row0" class="row_heading level1 row0" >beginners-mafia</th>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow0_col0" class="data row0 col0" >62</td>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow0_col1" class="data row0 col1" >26812</td>
#     </tr>    <tr>
#         <th id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddlevel1_row1" class="row_heading level1 row1" >vanilla</th>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow1_col0" class="data row1 col0" >14</td>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow1_col1" class="data row1 col1" >6317</td>
#     </tr>    <tr>
#         <th id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddlevel0_row2" class="row_heading level0 row2" rowspan=3>2</th>
#         <th id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddlevel1_row2" class="row_heading level1 row2" >classic</th>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow2_col0" class="data row2 col0" >36</td>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow2_col1" class="data row2 col1" >17390</td>
#     </tr>    <tr>
#         <th id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddlevel1_row3" class="row_heading level1 row3" >supernatural</th>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow3_col0" class="data row3 col0" >10</td>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow3_col1" class="data row3 col1" >5949</td>
#     </tr>    <tr>
#         <th id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddlevel1_row4" class="row_heading level1 row4" >vengeful</th>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow4_col0" class="data row4 col0" >13</td>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow4_col1" class="data row4 col1" >2222</td>
#     </tr>    <tr>
#         <th id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddlevel0_row5" class="row_heading level0 row5" rowspan=6>1</th>
#         <th id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddlevel1_row5" class="row_heading level1 row5" >bastard</th>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow5_col0" class="data row5 col0" >35</td>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow5_col1" class="data row5 col1" >21169</td>
#     </tr>    <tr>
#         <th id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddlevel1_row6" class="row_heading level1 row6" >byor</th>
#         <td id="T_7ec9c738_0df5_11e9_b29c_4ccc6a80a6ddrow6_col

# %% [markdown]
# ---------

# %% [markdown]
# # Exploring roles for "usefulness=3" games

# %%
p_roles = os.path.join(p_data, 'roles.csv')
df_roles = pd.read_csv(p_roles, header=0, encoding='utf-8')

# %%
df_roles.head()
# Out:
#    thread_num             user         role  num_posts            replaced_by
# 0      170712  BlackHeartKabal     replaced          9  randomgenericusername
# 1      170712       Dorsidwarf     observer          1                    NaN
# 2      170712   FallacyofUrist  game-master         43                    NaN
# 3      170712         IcyTea31         town         62                    NaN
# 4      170712     Maximum Spin        mafia         88                    NaN

# %% [markdown]
# We need to first figure out the roles for those who have been replaced.
#
# The map is `old_player -> new_player @ role`, we want to apply the role to the old_player too.

# %%
df_roles_fixed = df_roles.copy()

tbr = (df_roles_fixed['role']=='replaced')
df_roles_fixed['replacement_depth'] = 0

cols_fixed = list(df_roles.columns) + ['replacement_depth']

while tbr.sum():
    df_roles_fixed = df_roles_fixed.merge(
        df_roles_fixed, how='left', 
        left_on=['thread_num', 'replaced_by'], 
        right_on=['thread_num', 'user'], 
        suffixes=('', '_repl')
    )[cols_fixed + ['role_repl']]
    
    tbr = (df_roles_fixed['role']=='replaced')
    df_roles_fixed['role'][tbr] = df_roles_fixed['role_repl'][tbr]
    df_roles_fixed['replacement_depth'][tbr] += 1
    df_roles_fixed = df_roles_fixed[cols_fixed]

# %%
df_roles_fixed[df_roles_fixed['role']=='replaced'].shape
# Out:
# (0, 6)

# %%
df_roles_fixed.head()
# Out:
#    thread_num             user         role  num_posts            replaced_by  \
# 0      170712  BlackHeartKabal         town          9  randomgenericusername
# 1      170712       Dorsidwarf     observer          1                    NaN
# 2      170712   FallacyofUrist  game-master         43                    NaN
# 3      170712         IcyTea31         town         62                    NaN
# 4      170712     Maximum Spin        mafia         88                    NaN
#
#    replacement_depth
# 0                  1
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
df_post_stats = df_roles_fixed.groupby(['role'])['num_posts'].agg(['count', 'sum'])
df_post_stats.columns = ['games', 'posts']

# %%
df_post_stats.style.bar()
# Out:
# <style  type="text/css" >
#     #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.8%, transparent 0%);
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.1%, transparent 0%);
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 0%);
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.4%, transparent 0%);
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.3%, transparent 0%);
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.4%, transparent 0%);
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 71.2%, transparent 0%);
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.2%, transparent 0%);
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow5_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow5_col1 {
#             width:  10em;
#              height:  80%;
#         }</style>
# <table id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6dd" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >games</th>
#         <th class="col_heading level0 col1" >posts</th>
#     </tr>    <tr>
#         <th class="index_name level0" >role</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddlevel0_row0" class="row_heading level0 row0" >game-master</th>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow0_col0" class="data row0 col0" >80</td>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow0_col1" class="data row0 col1" >3592</td>
#     </tr>    <tr>
#         <th id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddlevel0_row1" class="row_heading level0 row1" >ic</th>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow1_col0" class="data row1 col0" >78</td>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow1_col1" class="data row1 col1" >958</td>
#     </tr>    <tr>
#         <th id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddlevel0_row2" class="row_heading level0 row2" >mafia</th>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow2_col0" class="data row2 col0" >182</td>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow2_col1" class="data row2 col1" >5950</td>
#     </tr>    <tr>
#         <th id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddlevel0_row3" class="row_heading level0 row3" >observer</th>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow3_col0" class="data row3 col0" >453</td>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow3_col1" class="data row3 col1" >1757</td>
#     </tr>    <tr>
#         <th id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddlevel0_row4" class="row_heading level0 row4" >town</th>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow4_col0" class="data row4 col0" >631</td>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow4_col1" class="data row4 col1" >20779</td>
#     </tr>    <tr>
#         <th id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddlevel0_row5" class="row_heading level0 row5" >unknown</th>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow5_col0" class="data row5 col0" >13</td>
#         <td id="T_7f0263f0_0df5_11e9_9e97_4ccc6a80a6ddrow5_col1" class="data row5 col1" >56</td>
#     </tr></tbody>
# </table>

# %%
df_mt_stats = df_post_stats.loc[['mafia', 'town'], ['games', 'posts']]

# %%
df_mt_stats.divide(df_mt_stats.sum(axis=0), axis=1)
# Out:
#           games     posts
# role
# mafia  0.223862  0.222605
# town   0.776138  0.777395
